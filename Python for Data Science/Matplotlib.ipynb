# %% [markdown]
# <a id='index'></a>

# %% [markdown]
# # Matplotlib
#
# ### Autor: Santiago González Montealegre

# %% [markdown]
# ## plot()
# `pyplot` is the module we will use to create our plots.
#
# Matplotlib works really well with _Pandas_.
#
#
# `plot()`function is used to create a plot from a Pandas Series or DataFrame. Inside the parenthesis it receives some parameters:
#
#
# - `kind= `: 'str'
#
#     - **line**
#     - **bar**
#         - `stacked= `: True/False
#     - **barh** for horizontal bar chart
#         - `stacked= `: True/False
#     - **hist**
#         - `bins= `: Integer
#     - **box**
#     - **area**
#         - `stacked= `: True/False
#     - **scatter**
#         - `x= `: Column name in the DF
#         - `y= `: Column name in the DF
#     - **pie**
#
# - `legend= `: True/False
#
# - `color= `: List of color hexes matching the number of lines or sets that we have
#     - [Color References](https://www.color-hex.com/)
#     - Color Palettes
#         - [Color Hunt](https://colorhunt.co/)
#         - [Color Space](https://mycolor.space/?hex=%23845EC2&sub=1)
#
# - `title= `: 'str'

# %% [markdown]
# ## Plot Formatting
#
# - `plt.xlabel('str')`
# - `plt.ylabel('str')`
# - `plt.subtitle('str')`
# - `plt.title('str')`
#
# Note: Title can be specified by the `plt.title('')` function or as an attribute or parameter inside the `plot(title='')` function.

# %% [markdown]
# ## Índice
#
# 1. [Line Plot](#line_plot)
# 1. [Bar Plot](#bar_plot)
# 1. [Box Plot](#box_plot)
# 1. [Histogram](#hist_plot)
# 1. [Area Plot](#area_plot)
# 1. [Scatter Plot](#scatter_plot)
# 1. [Pie Chart](#pie_plot)
# 1. [Plot Formatting](#formatting)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
s = pd.Series([18, 42, 9, 32, 81, 64, 3])

# kind = [line, bar, hist, ]
print(s.plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# <a id='line_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Line Plot

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)


df['year'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.year
df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month
df['month_name'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month_name()
df['day'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.day
df['day_name'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.day_name()

# https://sparkbyexamples.com/pandas/pandas-concatenate-two-columns/#:~:text=By%20use%20%2B%20operator%20simply%20you,does%20addition%20instead%20of%20concatenation.
df['month_day'] =  (df['day']).astype(str) + '-' + (df['month']).astype(str)
df.set_index('month_day', inplace=True)

#df.head(1)

# %%
df[df['month'] == 12][['cases', 'deaths']].plot()
# Out:
# <AxesSubplot:xlabel='month_day'>

# %% [markdown]
# <a id='bar_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Bar Plot

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month

#df.head(1)

# %%
graph = df.groupby('month')[['cases', 'deaths']].sum()
graph.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# <a id='box_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Box Plot

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month

#df.head(1)

# %%
df[df['month'] == 6]['cases'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='hist_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Histogram

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month

#df.head(1)

# %%
# bins parameter is not necessary
df[df['month'] == 12]['cases'].plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <a id='area_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Area Plot

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month

#df.head(1)

# %%
# stacked by default
df[df['month'] == 6][['cases', 'deaths']].plot(kind='area', stacked=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id='scatter_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Scatter Plot

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month

#df.head(1)

# %%
# we don't need to select the data on the DataFrame, because the scatter plot takes in the parameters the columns that we want
df[df['month'] == 6][['cases', 'deaths']].plot(kind='scatter', x='cases', y='deaths')

df[df['month'] == 6].plot(kind='scatter', x='cases', y='deaths')
# Out:
# <AxesSubplot:xlabel='cases', ylabel='deaths'>

# %% [markdown]
# <a id='pie_plot'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Pie Chart

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month
df['month_name'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month_name()
df['day_name'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.day_name()

#df.head(1)

# %%
df.groupby('day_name')['cases'].sum().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='cases'>

# %% [markdown]
# <a id='formatting'></a>
#
# [Índice](#index)

# %% [markdown]
# ## Plot Formatting Example

# %%
df = pd.read_csv('Datasets/ca-covid.csv')

df.drop(['state'], axis=1, inplace=True)

df['month'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.month
df['day'] = pd.to_datetime(df['date'], format='%d.%m.%y').dt.day

df.set_index('day', inplace=True)
#df.head(1)

# %%
# by default the xlabel corresponds to the index name
# by default the ylabel is empty

df[df['month'] == 6][['cases', 'deaths']].plot(kind='area',
                                               stacked=False, 
                                               legend=True,
                                               color=['#555588', '#55ffee'],
                                               #title='fjdfdjal'
                                               )
plt.xlabel('Days in June')
plt.ylabel('Number of')

# if u have many sub graphs (3 graphs in 1 big plot) the suptitle works for making a title for the big plot, however title works in each of the 3 graphs
# in this case there is not a real difference
plt.suptitle('California COVID-19')
plt.title('COVID-19 in June')
# Out:
# Text(0.5, 1.0, 'COVID-19 in June')
